# %%
import pandas as pd

# %%
data=pd.read_csv("fake_meta.csv")
data.columns
# Out:
# c:\users\hp\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1,5,6,7,8,9,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['Unnamed: 0',
#        ',favorite_count,follower_count,friends_count,hashtags,import pandas as pd,is_protected,is_verified,news_item,reply_to_id,retweet_count,tweet_created_at,tweet_id,user_created_at,user_id',
#        'favorite_count', 'follower_count', 'friends_count', 'hashtags',
#        'import pandas as pd', 'is_protected', 'is_verified', 'news_item',
#        'reply_to_id', 'retweet_count', 'tweet_created_at', 'tweet_id',
#        'user_created_at', 'user_id'],
#       dtype='object')

# %%
data=data.drop([ ',favorite_count,follower_count,friends_count,hashtags,import pandas as pd,is_protected,is_verified,news_item,reply_to_id,retweet_count,tweet_created_at,tweet_id,user_created_at,user_id','import pandas as pd','reply_to_id'],axis=1)
data
# Out:
#         Unnamed: 0  favorite_count  follower_count  friends_count  \
# 0                0             NaN             NaN            NaN
# 1                1             NaN             NaN            NaN
# 2                2             NaN             NaN            NaN
# 3                3             NaN             NaN            NaN
# 4                4             NaN             NaN            NaN
# 5                5             NaN             NaN            NaN
# 6                6             NaN             NaN            NaN
# 7                7             NaN             NaN            NaN
# 8                8             NaN             NaN            NaN
# 9                9             NaN             NaN            NaN
# 10              10             NaN             NaN            NaN
# 11              11             NaN             NaN            NaN
# 12              12             NaN             NaN            NaN
# ...

# %%
data=data.dropna(axis=0)

# %%
data.to_csv("fake_meta_cleaned.csv")

# %%
df=pd.read_csv("fake_meta_cleaned.csv")
df
# Out:
#         Unnamed: 0  Unnamed: 0.1  favorite_count  follower_count  \
# 0           105114        105114             0.0         30822.0
# 1           105115        105115             0.0         14693.0
# 2           105116        105116             0.0           810.0
# 3           105117        105117             5.0          6852.0
# 4           105118        105118             0.0          4884.0
# 5           105119        105119             0.0           117.0
# 6           105120        105120             0.0          2144.0
# 7           105121        105121             0.0           469.0
# 8           105122        105122             0.0           169.0
# 9           105123        105123             0.0           672.0
# 10          105124        105124             0.0        291000.0
# 11          105125        105125             0.0           600.0
# 12          105126        105126             0.0          5147.0
# ...

# %% [markdown]
# df.iloc[0][0]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'favorite_count', 'follower_count',
#        'friends_count', 'hashtags', 'is_protected', 'is_verified', 'news_item',
#        'retweet_count', 'tweet_created_at', 'tweet_id', 'user_created_at',
#        'user_id'],
#       dtype='object')

# %%
df=df.drop(['Unnamed: 0', 'Unnamed: 0.1'],axis=1)
df
# Out:
#         favorite_count  follower_count  friends_count  \
# 0                  0.0         30822.0        13897.0
# 1                  0.0         14693.0        17244.0
# 2                  0.0           810.0          764.0
# 3                  5.0          6852.0         1292.0
# 4                  0.0          4884.0         6339.0
# 5                  0.0           117.0            0.0
# 6                  0.0          2144.0         2685.0
# 7                  0.0           469.0         1668.0
# 8                  0.0           169.0          381.0
# 9                  0.0           672.0          125.0
# 10                 0.0        291000.0          706.0
# 11                 0.0           600.0         1183.0
# 12                 0.0          5147.0         2191.0
# 13                 0.0            28.0           40.0
# 14                 0.0          1417.0          344.0
# 15                 0.0          2114.0         1328.0
# ...

# %%
df.to_csv("fake_meta_cleaned.csv")
