# %%
import pandas as pd

# %%
d1=pd.read_csv("real_meta.csv",error_bad_lines=False)
d1.columns
# Out:
# c:\users\hp\appdata\local\programs\python\python36-32\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1,5,6,7,8,9,12,14) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Index(['Unnamed: 0',
#        ',favorite_count,follower_count,friends_count,hashtags,import pandas as pd,is_protected,is_verified,news_item,reply_to_id,retweet_count,tweet_created_at,tweet_id,user_created_at,user_id',
#        'favorite_count', 'follower_count', 'friends_count', 'hashtags',
#        'import pandas as pd', 'is_protected', 'is_verified', 'news_item',
#        'reply_to_id', 'retweet_count', 'tweet_created_at', 'tweet_id',
#        'user_created_at', 'user_id'],
#       dtype='object')

# %%
 d1=d1.drop([',favorite_count,follower_count,friends_count,hashtags,import pandas as pd,is_protected,is_verified,news_item,reply_to_id,retweet_count,tweet_created_at,tweet_id,user_created_at,user_id','import pandas as pd','reply_to_id'], axis=1)

# %%
d1=d1.dropna(axis=0)
d1
# Out:
#        Unnamed: 0  favorite_count  follower_count  friends_count  \
# 0               0             0.0             3.0           31.0
# 1               1            70.0      11728324.0       116346.0
# 2               2             0.0          1404.0          631.0
# 3               3             0.0          1117.0         3989.0
# 4               4             0.0            56.0           15.0
# 5               5             0.0          3228.0         2920.0
# 6               6             0.0         31283.0        23849.0
# 7               7             0.0         43715.0           47.0
# 8               8             0.0           617.0         1131.0
# 9               9             0.0           238.0         1106.0
# 10             10             0.0          4677.0          986.0
# 11             11             0.0           297.0           53.0
# 12             12             0.0            19.0           45.0
# ...

# %%
d1=d1.drop(['Unnamed: 0'],axis=1)

# %%
d1
# Out:
#        favorite_count  follower_count  friends_count  \
# 0                 0.0             3.0           31.0
# 1                70.0      11728324.0       116346.0
# 2                 0.0          1404.0          631.0
# 3                 0.0          1117.0         3989.0
# 4                 0.0            56.0           15.0
# 5                 0.0          3228.0         2920.0
# 6                 0.0         31283.0        23849.0
# 7                 0.0         43715.0           47.0
# 8                 0.0           617.0         1131.0
# 9                 0.0           238.0         1106.0
# 10                0.0          4677.0          986.0
# 11                0.0           297.0           53.0
# 12                0.0            19.0           45.0
# 13                0.0         19076.0        22740.0
# 14                0.0          1712.0         1792.0
# 15                0.0           206.0          148.0
# 16                0.0          2148.0         2868.0
# ...

# %%
d1.to_csv("real_meta_cleaned.csv")
